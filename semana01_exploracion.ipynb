# %%
import pandas as pd
import matplotlib.pyplot as plt

# Carga del dataset elegido (ajusta el nombre del archivo)
df = pd.read_csv("mi_dataset.csv")

# Exploracion inicial
print("Dimensiones (filas, columnas):", df.shape)
print("\nPrimeras filas:")
print(df.head())

print("\nTipos de datos:")
print(df.dtypes)

print("\nResumen estadistico:")
print(df.describe())

# Primer grafico: distribucion de una columna numerica
columna = df.select_dtypes("number").columns[0]
df[columna].hist(bins=20)
plt.title(f"Distribucion de {columna}")
plt.xlabel(columna); plt.ylabel("Frecuencia")
plt.tight_layout()
plt.savefig("distribucion.png")
plt.show()
# Out:
# Dimensiones (filas, columnas): (7, 2)
#
# Primeras filas:
#    edad  salario
# 0    20     1200
# 1    25     1800
# 2    30     2500
# 3    35     3100
# 4    40     3700
#
# Tipos de datos:
# edad       int64
# salario    int64
# dtype: object
#
# Resumen estadistico:
#             edad      salario
# count   7.000000     7.000000
# mean   35.000000  3042.857143
# std    10.801234  1297.249838
# min    20.000000  1200.000000
# 25%    27.500000  2150.000000
# 50%    35.000000  3100.000000
# 75%    42.500000  3950.000000
# max    50.000000  4800.000000
